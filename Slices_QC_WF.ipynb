# %%
from nipype.interfaces import fsl
from nipype.interfaces.io import DataSink, SelectFiles, DataGrabber 
from nipype.pipeline.engine import Node, Workflow, JoinNode, MapNode
from nipype.interfaces.utility import IdentityInterface, Function  
from os.path import abspath, expanduser, join

# %%
#Set variables
#subject_list = ['02-T2']

subject_list = ['02-T2', '06-T1', '07-T2','08-T1', '09-T2', '10-T1', '11-T1', '12-T1', '13-T1', '15-T1', '16-T1', '17-T1',
                '18-T1', '19-T1', '20-T1', '21-T1', '22-T1', '23-T1', '24-T1', '29-T1', '30-T1', '31-T1', '32-T1',
                '35-T1', '36-T1', '37-T1', '38-T1', '40-T1', '102-T1', '103-T1', '104-T1', '105-T1', '106-T1', '107-T1', '108-T1', '109-T1',
                '110-T1', '111-T1']

#subject_list = ['08-T1']#, '20-T1','22-T1','29-T1','31-T1','35-T1']

home = '/Volumes/group/proc/TIGERanalysis/qT1'
fpath = join(home, 'subjDir')
workflow_dir = join(home, 'workflow_qT1')
data_dir = join(home, 'DataDir_qT1')

# %%
#Setup Datasink, Infosource, Selectfiles

datasink = Node(DataSink(base_directory = data_dir),
                   name='datasink')

#Set infosource iterables
infosource = Node(IdentityInterface(fields=['subject_id']),
                  name="infosource")
infosource.iterables = [('subject_id', subject_list)]

#SelectFiles
template = dict(raw_qt1 = join(fpath,'{subject_id}/qt1_T1fit_final.nii.gz')
               )

sf = Node(SelectFiles(template, 
                      base_directory = home),
          name = 'sf')

# %%
slices = Node(fsl.Slicer(all_axial = True,
                         image_width = 1000,
                        out_file = 'qT1_fitted_QC.png'),
            name = 'slices')

# %%
sliceqc_flow = Workflow(name = 'sliceqc_flow')
sliceqc_flow.connect([(infosource, sf, [('subject_id','subject_id')]),
                      (sf, slices, [('raw_qt1', 'in_file')]),
                      (slices, datasink, [('out_file', '0_image_qc')])
                     ])
sliceqc_flow.base_dir = workflow_dir
sliceqc_flow.write_graph(graph2use = 'flat')
preproc = sliceqc_flow.run('MultiProc', plugin_args={'n_procs': 2})
# Out:
# 190411-10:34:59,849 nipype.workflow INFO:
# 	 Generated workflow graph: /Volumes/group/proc/TIGERanalysis/qT1/workflow_qT1/sliceqc_flow/graph.png (graph2use=flat, simple_form=True).
# 190411-10:34:59,864 nipype.workflow INFO:
# 	 Workflow sliceqc_flow settings: ['check', 'execution', 'logging', 'monitoring']
# 190411-10:35:02,107 nipype.workflow INFO:
# 	 Running in parallel.
# 190411-10:35:02,113 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 38 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 2/2.
# 190411-10:35:02,250 nipype.workflow INFO:
# 	 [Node] Setting-up "sliceqc_flow.sf" in "/Volumes/group/proc/TIGERanalysis/qT1/workflow_qT1/sliceqc_flow/_subject_id_111-T1/sf".
# 190411-10:35:02,253 nipype.workflow INFO:
# 	 [Node] Setting-up "sliceqc_flow.sf" in "/Volumes/group/proc/TIGERanalysis/qT1/workflow_qT1/sliceqc_flow/_subject_id_110-T1/sf".
# 190411-10:35:03,787 nipype.workflow INFO:
# 	 [Node] Running "sf" ("nipype.interfaces.io.SelectFiles")190411-10:35:03,923 nipype.workflow INFO:
# 	 [Node] Running "sf" ("nipype.interfaces.io.SelectFiles")
#
# 190411-10:35:04,119 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 36 jobs ready. Free memory (GB): 28.40/28.80, Free processors: 0/2.
#                      Currently running:
#                        * sliceqc_flow.sf
#                        * sliceqc_flow.sf
# 190411-10:35:04,764 nipype.workflow INFO:
# 	 [Node] Finished "sliceqc_flow.sf".
# 190411-10:35:04,974 nipype.workflow INFO:
# 	 [Node] Finished "sliceqc_flow.sf".
# 190411-10:35:06,118 nipype.workflow INFO:
# 	 [Job 0] Completed (sliceqc_flow.sf).
# 190411-10:35:06,120 nipype.workflow INFO:
# 	 [Job 3] Completed (sliceqc_flow.sf).
# 190411-10:35:06,123 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 38 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 2/2.
# 190411-10:35:06,319 nipype.workflow INFO:
# 	 [Node] Setting-up "sliceqc_flow.slices" in "/Volumes/group/proc/TIGERanalysis/qT1/workflow_qT1/sliceqc_flow/_subject_id_111-T1/slices".
# 190411-10:35:06,618 nipype.workflow INFO:
# 	 [Node] Setting-up "sliceqc_flow.slices" in "/Volumes/group/proc/TIGERanalysis/qT1/workflow_qT1/sliceqc_flow/_subject_id_110-T1/slices".
# 190411-10:35:08,124 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 36 jobs ready. Free memory (GB): 28.40/28.80, Free processors: 0/2.
#                      Currently running:
#                        * sliceqc_flow.slices
#                        * sliceqc_flow.slices
# 190411-10:35:08,169 nipype.workflow INFO:
# 	 [Node] Running "slices" ("nipype.interfaces.fsl.utils.Slicer"), a CommandLine Interface with command:
# slicer /Volumes/group/proc/TIGERanalysis/qT1/subjDir/111-T1/qt1_T1fit_final.nii.gz -L  -A 1000 qT1_fitted_QC.png190411-10:35:08,288 nipype.workflow INFO:
# 	 [Node] Running "slices" ("nipype.interfaces.fsl.utils.Slicer"), a CommandLine Interface with command:
# slicer /Volumes/group/proc/TIGERanalysis/qT1/subjDir/110-T1/qt1_T1fit_final.nii.gz -L  -A 1000 qT1_fitted_QC.png
#
# 190411-10:35:10,711 nipype.workflow INFO:
# 	 [Node] Finished "sliceqc_flow.slices".
# 190411-10:35:11,350 nipype.workflow INFO:
# 	 [Node] Finished "sliceqc_flow.slices".
# 190411-10:35:12,127 nipype.workflow INFO:
# 	 [Job 1] Completed (sliceqc_flow.slices).
# 190411-10:35:12,129 nipype.workflow INFO:
# 	 [Job 4] Completed (sliceqc_flow.slices).
# 190411-10:35:12,131 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 38 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 2/2.
# 190411-10:35:12,299 nipype.workflow INFO:
# 	 [Node] Setting-up "sliceqc_flow.datasink" in "/Volumes/group/proc/TIGERanalysis/qT1/workflow_qT1/sliceqc_flow/_subject_id_111-T1/datasink".
# 190411-10:35:12,469 nipype.workflow INFO:
# 	 [Node] Setting-up "sliceqc_flow.datasink" in "/Volumes/group/proc/TIGERanalysis/qT1/workflow_qT1/sliceqc_flow/_subject_id_110-T1/datasink".190411-10:35:12,787 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
#
# 190411-10:35:14,131 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 36 jobs ready. Free memory (GB): 28.40/28.80, Free processors: 0/2.
#                      Currently running:
#                        * sliceqc_flow.datasink
#                        * sliceqc_flow.datasink
# 190411-10:35:14,880 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 190411-10:35:16,680 nipype.workflow INFO:
# 	 [Node] Finished "sliceqc_flow.datasink".
# 190411-10:35:17,198 nipype.workflow INFO:
# 	 [Node] Finished "sliceqc_flow.datasink".
# 190411-10:35:18,136 nipype.workflow INFO:
# 	 [Job 2] Completed (sliceqc_flow.datasink).
# 190411-10:35:18,138 nipype.workflow INFO:
# 	 [Job 5] Completed (sliceqc_flow.datasink).
# 190411-10:35:18,140 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 36 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 2/2.
# 190411-10:35:18,253 nipype.workflow INFO:
# 	 [Node] Setting-up "sliceqc_flow.sf" in "/Volumes/group/proc/TIGERanalysis/qT1/workflow_qT1/sliceqc_flow/_subject_id_109-T1/sf".
# 190411-10:35:18,256 nipype.workflow INFO:
# 	 [Node] Setting-up "sliceqc_flow.sf" in "/Volumes/group/proc/TIGERanalysis/qT1/workflow_qT1/sliceqc_flow/_subject_id_108-T1/sf".
# 190411-10:35:20,141 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 34 jobs ready. Free memory (GB): 28.40/28.80, Free processors: 0/2.
#                      Currently running:
#                        * sliceqc_flow.sf
#                        * sliceqc_flow.sf
# 190411-10:35:20,400 nipype.workflow INFO:
# 	 [Node] Running "sf" ("nipype.interfaces.io.SelectFiles")190411-10:35:20,597 nipype.workflow INFO:
# 	 [Node] Running "sf" ("nipype.interfaces.io.SelectFiles")
#
# 190411-10:35:22,629 nipype.workflow INFO:
# 	 [Node] Finished "sliceqc_flow.sf".
# 190411-10:35:22,867 nipype.workflow INFO:
# 	 [Node] Finished "sliceqc_flow.sf".
# 190411-10:35:24,143 nipype.workflow INFO:
# 	 [Job 6] Completed (sliceqc_flow.sf).
# 190411-10:35:24,145 nipype.workflow INFO:
# 	 [Job 9] Completed (sliceqc_flow.sf).
# 190411-10:35:24,147 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 36 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 2/2.
# 190411-10:35:24,315 nipype.workflow INFO:
# 	 [Node] Setting-up "sliceqc_flow.slices" in "/Volumes/group/proc/TIGERanalysis/qT1/workflow_qT1/sliceqc_flow/_subject_id_109-T1/slices".
# 190411-10:35:24,523 nipype.workflow INFO:
# 	 [Node] Setting-up "sliceqc_flow.slices" in "/Volumes/group/proc/TIGERanalysis/qT1/workflow_qT1/sliceqc_flow/_subject_id_108-T1/slices".190411-10:35:25,441 nipype.workflow INFO:
# 	 [Node] Running "slices" ("nipype.interfaces.fsl.utils.Slicer"), a CommandLine Interface with command:
# slicer /Volumes/group/proc/TIGERanalysis/qT1/subjDir/109-T1/qt1_T1fit_final.nii.gz -L  -A 1000 qT1_fitted_QC.png
#
# 190411-10:35:26,144 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 34 jobs ready. Free memory (GB): 28.40/28.80, Free processors: 0/2.
#                      Currently running:
#                        * sliceqc_flow.slices
#                        * sliceqc_flow.slices
# 190411-10:35:28,620 nipype.workflow INFO:
# 	 [Node] Running "slices" ("nipype.interfaces.fsl.utils.Slicer"), a CommandLine Interface with command:
# slicer /Volumes/group/proc/TIGERanalysis/qT1/subjDir/108-T1/qt1_T1fit_final.nii.gz -L  -A 1000 qT1_fitted_QC.png
# 190411-10:35:32,144 nipype.workflow INFO:
# 	 [Node] Finished "sliceqc_flow.slices".
# 190411-10:35:32,467 nipype.workflow INFO:
# 	 [Node] Finished "sliceqc_flow.slices".
# 190411-10:35:34,151 nipype.workflow INFO:
# 	 [Job 7] Completed (sliceqc_flow.slices).
# 190411-10:35:34,152 nipype.workflow INFO:
# 	 [Job 10] Completed (sliceqc_flow.slices).
# 190411-10:35:34,154 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 36 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 2/2.
# 190411-10:35:34,328 nipype.workflow INFO:
# 	 [Node] Setting-up "sliceqc_flow.datasink" in "/Volumes/group/proc/TIGERanalysis/qT1/workflow_qT1/sliceqc_flow/_subject_id_109-T1/datasink".
# 190411-10:35:34,563 nipype.workflow INFO:
# 	 [Node] Setting-up "sliceqc_flow.datasink" in "/Volumes/group/proc/TIGERanalysis/qT1/workflow_qT1/sliceqc_flow/_subject_id_108-T1/datasink".190411-10:35:35,104 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
#
# 190411-10:35:36,151 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 34 jobs ready. Free memory (GB): 28.40/28.80, Free processors: 0/2.
#                      Currently running:
#                        * sliceqc_flow.datasink
#                        * sliceqc_flow.datasink
# 190411-10:35:37,23 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 190411-10:35:38,936 nipype.workflow INFO:
# 	 [Node] Finished "sliceqc_flow.datasink".
# 190411-10:35:39,831 nipype.workflow INFO:
# 	 [Node] Finished "sliceqc_flow.datasink".
# 190411-10:35:40,159 nipype.workflow INFO:
# 	 [Job 8] Completed (sliceqc_flow.datasink).
# 190411-10:35:40,160 nipype.workflow INFO:
# 	 [Job 11] Completed (sliceqc_flow.datasink).
# 190411-10:35:40,163 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 34 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 2/2.
# 190411-10:35:40,277 nipype.workflow INFO:
# 	 [Node] Setting-up "sliceqc_flow.sf" in "/Volumes/group/proc/TIGERanalysis/qT1/workflow_qT1/sliceqc_flow/_subject_id_107-T1/sf".
# 190411-10:35:40,279 nipype.workflow INFO:
# 	 [Node] Setting-up "sliceqc_flow.sf" in "/Volumes/group/proc/TIGERanalysis/qT1/workflow_qT1/sliceqc_flow/_subject_id_106-T1/sf".
# 190411-10:35:42,161 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 32 jobs ready. Free memory (GB): 28.40/28.80, Free processors: 0/2.
#                      Currently running:
#                        * sliceqc_flow.sf
#                        * sliceqc_flow.sf
# 190411-10:35:42,525 nipype.workflow INFO:
# 	 [Node] Running "sf" ("nipype.interfaces.io.SelectFiles")190411-10:35:42,722 nipype.workflow INFO:
# 	 [Node] Running "sf" ("nipype.interfaces.io.SelectFiles")
#
# 190411-10:35:43,653 nipype.workflow INFO:
# 	 [Node] Finished "sliceqc_flow.sf".
# 190411-10:35:43,991 nipype.workflow INFO:
# 	 [Node] Finished "sliceqc_flow.sf".
# 190411-10:35:44,165 nipype.workflow INFO:
# 	 [Job 12] Completed (sliceqc_flow.sf).
# 190411-10:35:44,166 nipype.workflow INFO:
# 	 [Job 15] Completed (sliceqc_flow.sf).
# 190411-10:35:44,169 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 34 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 2/2.
# 190411-10:35:44,332 nipype.workflow INFO:
# 	 [Node] Setting-up "sliceqc_flow.slices" in "/Volumes/group/proc/TIGERanalysis/qT1/workflow_qT1/sliceqc_flow/_subject_id_107-T1/slices".
# 190411-10:35:44,590 nipype.workflow INFO:
# 	 [Node] Setting-up "sliceqc_flow.slices" in "/Volumes/group/proc/TIGERanalysis/qT1/workflow_qT1/sliceqc_flow/_subject_id_106-T1/slices".
# 190411-10:35:45,411 nipype.workflow INFO:
# 	 [Node] Running "slices" ("nipype.interfaces.fsl.utils.Slicer"), a CommandLine Interface with command:
# slicer /Volumes/group/proc/TIGERanalysis/qT1/subjDir/107-T1/qt1_T1fit_final.nii.gz -L  -A 1000 qT1_fitted_QC.png
# 190411-10:35:45,848 nipype.workflow INFO:
# 	 [Node] Running "slices" ("nipype.interfaces.fsl.utils.Slicer"), a CommandLine Interface with command:
# slicer /Volumes/group/proc/TIGERanalysis/qT1/subjDir/106-T1/qt1_T1fit_final.nii.gz -L  -A 1000 qT1_fitted_QC.png
# 190411-10:35:46,168 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 32 jobs ready. Free memory (GB): 28.40/28.80, Free processors: 0/2.
#                      Currently running:
#                        * sliceqc_flow.slices
#                        * sliceqc_flow.slices
# 190411-10:35:50,79 nipype.workflow INFO:
# 	 [Node] Finished "sliceqc_flow.slices".
# 190411-10:35:50,174 nipype.workflow INFO:
# 	 [Job 16] Completed (sliceqc_flow.slices).
# 190411-10:35:50,177 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 33 jobs ready. Free memory (GB): 28.60/28.80, Free processors: 1/2.
#                      Currently running:
#                        * sliceqc_flow.slices
# 190411-10:35:50,537 nipype.workflow INFO:
# 	 [Node] Finished "sliceqc_flow.slices".
# 190411-10:35:50,598 nipype.workflow INFO:
# 	 [Node] Setting-up "sliceqc_flow.datasink" in "/Volumes/group/proc/TIGERanalysis/qT1/workflow_qT1/sliceqc_flow/_subject_id_106-T1/datasink".
# 190411-10:35:51,292 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 190411-10:35:52,177 nipype.workflow INFO:
# 	 [Job 13] Completed (sliceqc_flow.slices).
# 190411-10:35:52,180 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 33 jobs ready. Free memory (GB): 28.60/28.80, Free processors: 1/2.
#                      Currently running:
#                        * sliceqc_flow.datasink
# 190411-10:35:52,872 nipype.workflow INFO:
# 	 [Node] Finished "sliceqc_flow.datasink".
# 190411-10:35:52,928 nipype.workflow INFO:
# 	 [Node] Setting-up "sliceqc_flow.datasink" in "/Volumes/group/proc/TIGERanalysis/qT1/workflow_qT1/sliceqc_flow/_subject_id_107-T1/datasink".
# 190411-10:35:54,180 nipype.workflow INFO:
# 	 [Job 17] Completed (sliceqc_flow.datasink).
# 190411-10:35:54,182 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 32 jobs ready. Free memory (GB): 28.60/28.80, Free processors: 1/2.
#                      Currently running:
#                        * sliceqc_flow.datasink
# 190411-10:35:54,296 nipype.workflow INFO:
# 	 [Node] Setting-up "sliceqc_flow.sf" in "/Volumes/group/proc/TIGERanalysis/qT1/workflow_qT1/sliceqc_flow/_subject_id_105-T1/sf".
# 190411-10:35:56,181 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 31 jobs ready. Free memory (GB): 28.40/28.80, Free processors: 0/2.
#                      Currently running:
#                        * sliceqc_flow.sf
#                        * sliceqc_flow.datasink
# 190411-10:35:56,233 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 190411-10:35:56,845 nipype.workflow INFO:
# 	 [Node] Running "sf" ("nipype.interfaces.io.SelectFiles")
# 190411-10:35:57,687 nipype.workflow INFO:
# 	 [Node] Finished "sliceqc_flow.sf".
# 190411-10:35:58,181 nipype.workflow INFO:
# 	 [Job 18] Completed (sliceqc_flow.sf).
# 190411-10:35:58,183 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 32 jobs ready. Free memory (GB): 28.60/28.80, Free processors: 1/2.
#                      Currently running:
#                        * sliceqc_flow.datasink
# 190411-10:35:58,339 nipype.workflow INFO:
# 	 [Node] Finished "sliceqc_flow.datasink".
# 190411-10:35:58,394 nipype.workflow INFO:
# 	 [Node] Setting-up "sliceqc_flow.slices" in "/Volumes/group/proc/TIGERanalysis/qT1/workflow_qT1/sliceqc_flow/_subject_id_105-T1/slices".
# 190411-10:35:59,609 nipype.workflow INFO:
# 	 [Node] Running "slices" ("nipype.interfaces.fsl.utils.Slicer"), a CommandLine Interface with command:
# slicer /Volumes/group/proc/TIGERanalysis/qT1/subjDir/105-T1/qt1_T1fit_final.nii.gz -L  -A 1000 qT1_fitted_QC.png
# 190411-10:36:00,181 nipype.workflow INFO:
# 	 [Job 14] Completed (sliceqc_flow.datasink).
# 190411-10:36:00,184 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 31 jobs ready. Free memory (GB): 28.60/28.80, Free processors: 1/2.
#                      Currently running:
#                        * sliceqc_flow.slices
# 190411-10:36:00,299 nipype.workflow INFO:
# 	 [Node] Setting-up "sliceqc_flow.sf" in "/Volumes/group/proc/TIGERanalysis/qT1/workflow_qT1/sliceqc_flow/_subject_id_104-T1/sf".
# 190411-10:36:02,184 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 30 jobs ready. Free memory (GB): 28.40/28.80, Free processors: 0/2.
#                      Currently running:
#                        * sliceqc_flow.sf
#                        * sliceqc_flow.slices
# 190411-10:36:02,816 nipype.workflow INFO:
# 	 [Node] Running "sf" ("nipype.interfaces.io.SelectFiles")
# 190411-10:36:05,232 nipype.workflow INFO:
# 	 [Node] Finished "sliceqc_flow.sf".
# 190411-10:36:05,423 nipype.workflow INFO:
# 	 [Node] Finished "sliceqc_flow.slices".
# 190411-10:36:06,192 nipype.workflow INFO:
# 	 [Job 19] Completed (sliceqc_flow.slices).
# 190411-10:36:06,193 nipype.workflow INFO:
# 	 [Job 21] Completed (sliceqc_flow.sf).
# 190411-10:36:06,196 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 32 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 2/2.
# 190411-10:36:06,317 nipype.workflow INFO:
# 	 [Node] Setting-up "sliceqc_flow.datasink" in "/Volumes/group/proc/TIGERanalysis/qT1/workflow_qT1/sliceqc_flow/_subject_id_105-T1/datasink".
# 190411-10:36:06,326 nipype.workflow INFO:
# 	 [Node] Setting-up "sliceqc_flow.slices" in "/Volumes/group/proc/TIGERanalysis/qT1/workflow_qT1/sliceqc_flow/_subject_id_104-T1/slices".
# 190411-10:36:08,192 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 30 jobs ready. Free memory (GB): 28.40/28.80, Free processors: 0/2.
#                      Currently running:
#                        * sliceqc_flow.slices
#                        * sliceqc_flow.datasink
# 190411-10:36:09,58 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")190411-10:36:09,811 nipype.workflow INFO:
# 	 [Node] Running "slices" ("nipype.interfaces.fsl.utils.Slicer"), a CommandLine Interface with command:
# slicer /Volumes/group/proc/TIGERanalysis/qT1/subjDir/104-T1/qt1_T1fit_final.nii.gz -L  -A 1000 qT1_fitted_QC.png
#
# 190411-10:36:12,191 nipype.workflow INFO:
# 	 [Node] Finished "sliceqc_flow.datasink".
# 190411-10:36:13,179 nipype.workflow INFO:
# 	 [Node] Finished "sliceqc_flow.slices".
# 190411-10:36:14,199 nipype.workflow INFO:
# 	 [Job 20] Completed (sliceqc_flow.datasink).
# 190411-10:36:14,200 nipype.workflow INFO:
# 	 [Job 22] Completed (sliceqc_flow.slices).
# 190411-10:36:14,203 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 31 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 2/2.
# 190411-10:36:14,371 nipype.workflow INFO:
# 	 [Node] Setting-up "sliceqc_flow.datasink" in "/Volumes/group/proc/TIGERanalysis/qT1/workflow_qT1/sliceqc_flow/_subject_id_104-T1/datasink".
# 190411-10:36:14,374 nipype.workflow INFO:
# 	 [Node] Setting-up "sliceqc_flow.sf" in "/Volumes/group/proc/TIGERanalysis/qT1/workflow_qT1/sliceqc_flow/_subject_id_103-T1/sf".
# 190411-10:36:16,201 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 29 jobs ready. Free memory (GB): 28.40/28.80, Free processors: 0/2.
#                      Currently running:
#                        * sliceqc_flow.sf
#                        * sliceqc_flow.datasink
# 190411-10:36:17,41 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")190411-10:36:17,198 nipype.workflow INFO:
# 	 [Node] Running "sf" ("nipype.interfaces.io.SelectFiles")
#
# 190411-10:36:18,160 nipype.workflow INFO:
# 	 [Node] Finished "sliceqc_flow.sf".
# 190411-10:36:18,610 nipype.workflow INFO:
# 	 [Node] Finished "sliceqc_flow.datasink".
# 190411-10:36:20,207 nipype.workflow INFO:
# 	 [Job 23] Completed (sliceqc_flow.datasink).
# 190411-10:36:20,209 nipype.workflow INFO:
# 	 [Job 24] Completed (sliceqc_flow.sf).
# 190411-10:36:20,212 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 30 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 2/2.
# 190411-10:36:20,376 nipype.workflow INFO:
# 	 [Node] Setting-up "sliceqc_flow.slices" in "/Volumes/group/proc/TIGERanalysis/qT1/workflow_qT1/sliceqc_flow/_subject_id_103-T1/slices".
# 190411-10:36:20,378 nipype.workflow INFO:
# 	 [Node] Setting-up "sliceqc_flow.sf" in "/Volumes/group/proc/TIGERanalysis/qT1/workflow_qT1/sliceqc_flow/_subject_id_102-T1/sf".
# 190411-10:36:22,209 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 28 jobs ready. Free memory (GB): 28.40/28.80, Free processors: 0/2.
#                      Currently running:
#                        * sliceqc_flow.sf
#                        * sliceqc_flow.slices
# 190411-10:36:24,417 nipype.workflow INFO:
# 	 [Node] Running "sf" ("nipype.interfaces.io.SelectFiles")190411-10:36:24,516 nipype.workflow INFO:
# 	 [Node] Running "slices" ("nipype.interfaces.fsl.utils.Slicer"), a CommandLine Interface with command:
# slicer /Volumes/group/proc/TIGERanalysis/qT1/subjDir/103-T1/qt1_T1fit_final.nii.gz -L  -A 1000 qT1_fitted_QC.png
#
# 190411-10:36:25,201 nipype.workflow INFO:
# 	 [Node] Finished "sliceqc_flow.sf".
# 190411-10:36:26,208 nipype.workflow INFO:
# 	 [Job 27] Completed (sliceqc_flow.sf).
# 190411-10:36:26,211 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 29 jobs ready. Free memory (GB): 28.60/28.80, Free processors: 1/2.
#                      Currently running:
#                        * sliceqc_flow.slices
# 190411-10:36:26,388 nipype.workflow INFO:
# 	 [Node] Setting-up "sliceqc_flow.slices" in "/Volumes/group/proc/TIGERanalysis/qT1/workflow_qT1/sliceqc_flow/_subject_id_102-T1/slices".
# 190411-10:36:27,837 nipype.workflow INFO:
# 	 [Node] Running "slices" ("nipype.interfaces.fsl.utils.Slicer"), a CommandLine Interface with command:
# slicer /Volumes/group/proc/TIGERanalysis/qT1/subjDir/102-T1/qt1_T1fit_final.nii.gz -L  -A 1000 qT1_fitted_QC.png
# 190411-10:36:28,213 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 28 jobs ready. Free memory (GB): 28.40/28.80, Free processors: 0/2.
#                      Currently running:
#                        * sliceqc_flow.slices
#                        * sliceqc_flow.slices
# 190411-10:36:29,268 nipype.workflow INFO:
# 	 [Node] Finished "sliceqc_flow.slices".
# 190411-10:36:30,212 nipype.workflow INFO:
# 	 [Job 25] Completed (sliceqc_flow.slices).
# 190411-10:36:30,216 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 29 jobs ready. Free memory (GB): 28.60/28.80, Free processors: 1/2.
#                      Currently running:
#                        * sliceqc_flow.slices
# 190411-10:36:30,620 nipype.workflow INFO:
# 	 [Node] Setting-up "sliceqc_flow.datasink" in "/Volumes/group/proc/TIGERanalysis/qT1/workflow_qT1/sliceqc_flow/_subject_id_103-T1/datasink".
# 190411-10:36:32,215 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 28 jobs ready. Free memory (GB): 28.40/28.80, Free processors: 0/2.
#                      Currently running:
#                        * sliceqc_flow.datasink
#                        * sliceqc_flow.slices
# 190411-10:36:30,829 nipype.workflow INFO:
# 	 [Node] Finished "sliceqc_flow.slices".190411-10:36:32,425 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
#
# 190411-10:36:33,683 nipype.workflow INFO:
# 	 [Node] Finished "sliceqc_flow.datasink".
# 190411-10:36:34,216 nipype.workflow INFO:
# 	 [Job 28] Completed (sliceqc_flow.slices).
# 190411-10:36:34,218 nipype.workflow INFO:
# 	 [Job 26] Completed (sliceqc_flow.datasink).
# 190411-10:36:34,221 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 29 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 2/2.
# 190411-10:36:34,454 nipype.workflow INFO:
# 	 [Node] Setting-up "sliceqc_flow.datasink" in "/Volumes/group/proc/TIGERanalysis/qT1/workflow_qT1/sliceqc_flow/_subject_id_102-T1/datasink".
# 190411-10:36:34,455 nipype.workflow INFO:
# 	 [Node] Setting-up "sliceqc_flow.sf" in "/Volumes/group/proc/TIGERanalysis/qT1/workflow_qT1/sliceqc_flow/_subject_id_40-T1/sf".
# 190411-10:36:36,217 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 27 jobs ready. Free memory (GB): 28.40/28.80, Free processors: 0/2.
#                      Currently running:
#                        * sliceqc_flow.sf
#                        * sliceqc_flow.datasink
# 190411-10:36:37,197 nipype.workflow INFO:
# 	 [Node] Running "sf" ("nipype.interfaces.io.SelectFiles")190411-10:36:38,427 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
#
# 190411-10:36:40,392 nipype.workflow INFO:
# 	 [Node] Finished "sliceqc_flow.sf".
# 190411-10:36:42,133 nipype.workflow INFO:
# 	 [Node] Finished "sliceqc_flow.datasink".
# 190411-10:36:42,222 nipype.workflow INFO:
# 	 [Job 29] Completed (sliceqc_flow.datasink).
# 190411-10:36:42,225 nipype.workflow INFO:
# 	 [Job 30] Completed (sliceqc_flow.sf).
# 190411-10:36:42,229 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 28 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 2/2.
# 190411-10:36:42,408 nipype.workflow INFO:
# 	 [Node] Setting-up "sliceqc_flow.slices" in "/Volumes/group/proc/TIGERanalysis/qT1/workflow_qT1/sliceqc_flow/_subject_id_40-T1/slices".
# 190411-10:36:42,410 nipype.workflow INFO:
# 	 [Node] Setting-up "sliceqc_flow.sf" in "/Volumes/group/proc/TIGERanalysis/qT1/workflow_qT1/sliceqc_flow/_subject_id_38-T1/sf".
# 190411-10:36:44,226 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 26 jobs ready. Free memory (GB): 28.40/28.80, Free processors: 0/2.
#                      Currently running:
#                        * sliceqc_flow.sf
#                        * sliceqc_flow.slices
# 190411-10:36:43,901 nipype.workflow INFO:
# 	 [Node] Running "sf" ("nipype.interfaces.io.SelectFiles")190411-10:36:44,445 nipype.workflow INFO:
# 	 [Node] Running "slices" ("nipype.interfaces.fsl.utils.Slicer"), a CommandLine Interface with command:
# slicer /Volumes/group/proc/TIGERanalysis/qT1/subjDir/40-T1/qt1_T1fit_final.nii.gz -L  -A 1000 qT1_fitted_QC.png
#
# 190411-10:36:46,127 nipype.workflow INFO:
# 	 [Node] Finished "sliceqc_flow.sf".
# 190411-10:36:46,225 nipype.workflow INFO:
# 	 [Job 33] Completed (sliceqc_flow.sf).
# 190411-10:36:46,228 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 27 jobs ready. Free memory (GB): 28.60/28.80, Free processors: 1/2.
#                      Currently running:
#                        * sliceqc_flow.slices
# 190411-10:36:46,447 nipype.workflow INFO:
# 	 [Node] Setting-up "sliceqc_flow.slices" in "/Volumes/group/proc/TIGERanalysis/qT1/workflow_qT1/sliceqc_flow/_subject_id_38-T1/slices".
# 190411-10:36:48,181 nipype.workflow INFO:
# 	 [Node] Running "slices" ("nipype.interfaces.fsl.utils.Slicer"), a CommandLine Interface with command:
# slicer /Volumes/group/proc/TIGERanalysis/qT1/subjDir/38-T1/qt1_T1fit_final.nii.gz -L  -A 1000 qT1_fitted_QC.png
# 190411-10:36:48,227 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 26 jobs ready. Free memory (GB): 28.40/28.80, Free processors: 0/2.
#                      Currently running:
#                        * sliceqc_flow.slices
#                        * sliceqc_flow.slices
# 190411-10:36:48,378 nipype.workflow INFO:
# 	 [Node] Finished "sliceqc_flow.slices".
# 190411-10:36:50,226 nipype.workflow INFO:
# 	 [Job 31] Completed (sliceqc_flow.slices).
# 190411-10:36:50,229 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 27 jobs ready. Free memory (GB): 28.60/28.80, Free processors: 1/2.
#                      Currently running:
#                        * sliceqc_flow.slices
# 190411-10:36:50,385 nipype.workflow INFO:
# 	 [Node] Finished "sliceqc_flow.slices".
# 190411-10:36:50,438 nipype.workflow INFO:
# 	 [Node] Setting-up "sliceqc_flow.datasink" in "/Volumes/group/proc/TIGERanalysis/qT1/workflow_qT1/sliceqc_flow/_subject_id_40-T1/datasink".
# 190411-10:36:51,265 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 190411-10:36:52,228 nipype.workflow INFO:
# 	 [Job 34] Completed (sliceqc_flow.slices).
# 190411-10:36:52,231 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 27 jobs ready. Free memory (GB): 28.60/28.80, Free processors: 1/2.
#                      Currently running:
#                        * sliceqc_flow.datasink
# 190411-10:36:52,553 nipype.workflow INFO:
# 	 [Node] Setting-up "sliceqc_flow.datasink" in "/Volumes/group/proc/TIGERanalysis/qT1/workflow_qT1/sliceqc_flow/_subject_id_38-T1/datasink".
# 190411-10:36:53,9 nipype.workflow INFO:
# 	 [Node] Finished "sliceqc_flow.datasink".190411-10:36:53,640 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
#
# 190411-10:36:54,230 nipype.workflow INFO:
# 	 [Job 32] Completed (sliceqc_flow.datasink).
# 190411-10:36:54,232 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 26 jobs ready. Free memory (GB): 28.60/28.80, Free processors: 1/2.
#                      Currently running:
#                        * sliceqc_flow.datasink
# 190411-10:36:54,344 nipype.workflow INFO:
# 	 [Node] Setting-up "sliceqc_flow.sf" in "/Volumes/group/proc/TIGERanalysis/qT1/workflow_qT1/sliceqc_flow/_subject_id_37-T1/sf".
# 190411-10:36:56,101 nipype.workflow INFO:
# 	 [Node] Running "sf" ("nipype.interfaces.io.SelectFiles")
# 190411-10:36:56,236 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 25 jobs ready. Free memory (GB): 28.40/28.80, Free processors: 0/2.
#                      Currently running:
#                        * sliceqc_flow.sf
#                        * sliceqc_flow.datasink
# 190411-10:36:57,747 nipype.workflow INFO:
# 	 [Node] Finished "sliceqc_flow.datasink".
# 190411-10:36:57,947 nipype.workflow INFO:
# 	 [Node] Finished "sliceqc_flow.sf".
# 190411-10:36:58,238 nipype.workflow INFO:
# 	 [Job 35] Completed (sliceqc_flow.datasink).
# 190411-10:36:58,240 nipype.workflow INFO:
# 	 [Job 36] Completed (sliceqc_flow.sf).
# 190411-10:36:58,243 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 26 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 2/2.
# 190411-10:36:58,442 nipype.workflow INFO:
# 	 [Node] Setting-up "sliceqc_flow.slices" in "/Volumes/group/proc/TIGERanalysis/qT1/workflow_qT1/sliceqc_flow/_subject_id_37-T1/slices".
# 190411-10:36:58,445 nipype.workflow INFO:
# 	 [Node] Setting-up "sliceqc_flow.sf" in "/Volumes/group/proc/TIGERanalysis/qT1/workflow_qT1/sliceqc_flow/_subject_id_36-T1/sf".
# 190411-10:37:00,240 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 24 jobs ready. Free memory (GB): 28.40/28.80, Free processors: 0/2.
#                      Currently running:
#                        * sliceqc_flow.sf
#                        * sliceqc_flow.slices
# 190411-10:37:03,286 nipype.workflow INFO:
# 	 [Node] Running "sf" ("nipype.interfaces.io.SelectFiles")190411-10:37:03,404 nipype.workflow INFO:
# 	 [Node] Running "slices" ("nipype.interfaces.fsl.utils.Slicer"), a CommandLine Interface with command:
# slicer /Volumes/group/proc/TIGERanalysis/qT1/subjDir/37-T1/qt1_T1fit_final.nii.gz -L  -A 1000 qT1_fitted_QC.png
#
# 190411-10:37:04,20 nipype.workflow INFO:
# 	 [Node] Finished "sliceqc_flow.sf".
# 190411-10:37:04,245 nipype.workflow INFO:
# 	 [Job 39] Completed (sliceqc_flow.sf).
# 190411-10:37:04,247 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 25 jobs ready. Free memory (GB): 28.60/28.80, Free processors: 1/2.
#                      Currently running:
#                        * sliceqc_flow.slices
# 190411-10:37:04,457 nipype.workflow INFO:
# 	 [Node] Setting-up "sliceqc_flow.slices" in "/Volumes/group/proc/TIGERanalysis/qT1/workflow_qT1/sliceqc_flow/_subject_id_36-T1/slices".
# 190411-10:37:06,250 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 24 jobs ready. Free memory (GB): 28.40/28.80, Free processors: 0/2.
#                      Currently running:
#                        * sliceqc_flow.slices
#                        * sliceqc_flow.slices
# 190411-10:37:06,962 nipype.workflow INFO:
# 	 [Node] Running "slices" ("nipype.interfaces.fsl.utils.Slicer"), a CommandLine Interface with command:
# slicer /Volumes/group/proc/TIGERanalysis/qT1/subjDir/36-T1/qt1_T1fit_final.nii.gz -L  -A 1000 qT1_fitted_QC.png
# 190411-10:37:07,648 nipype.workflow INFO:
# 	 [Node] Finished "sliceqc_flow.slices".
# 190411-10:37:08,250 nipype.workflow INFO:
# 	 [Job 37] Completed (sliceqc_flow.slices).
# 190411-10:37:08,252 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 25 jobs ready. Free memory (GB): 28.60/28.80, Free processors: 1/2.
#                      Currently running:
#                        * sliceqc_flow.slices
# 190411-10:37:09,374 nipype.workflow INFO:
# 	 [Node] Setting-up "sliceqc_flow.datasink" in "/Volumes/group/proc/TIGERanalysis/qT1/workflow_qT1/sliceqc_flow/_subject_id_37-T1/datasink".
# 190411-10:37:10,74 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 190411-10:37:10,255 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 24 jobs ready. Free memory (GB): 28.40/28.80, Free processors: 0/2.
#                      Currently running:
#                        * sliceqc_flow.datasink
#                        * sliceqc_flow.slices
# 190411-10:37:12,924 nipype.workflow INFO:
# 	 [Node] Finished "sliceqc_flow.slices".
# 190411-10:37:14,255 nipype.workflow INFO:
# 	 [Job 40] Completed (sliceqc_flow.slices).
# 190411-10:37:14,257 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 25 jobs ready. Free memory (GB): 28.60/28.80, Free processors: 1/2.
#                      Currently running:
#                        * sliceqc_flow.datasink
# 190411-10:37:14,943 nipype.workflow INFO:
# 	 [Node] Finished "sliceqc_flow.datasink".
# 190411-10:37:15,32 nipype.workflow INFO:
# 	 [Node] Setting-up "sliceqc_flow.datasink" in "/Volumes/group/proc/TIGERanalysis/qT1/workflow_qT1/sliceqc_flow/_subject_id_36-T1/datasink".
# 190411-10:37:16,115 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 190411-10:37:16,255 nipype.workflow INFO:
# 	 [Job 38] Completed (sliceqc_flow.datasink).
# 190411-10:37:16,258 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 24 jobs ready. Free memory (GB): 28.60/28.80, Free processors: 1/2.
#                      Currently running:
#                        * sliceqc_flow.datasink
# 190411-10:37:16,385 nipype.workflow INFO:
# 	 [Node] Setting-up "sliceqc_flow.sf" in "/Volumes/group/proc/TIGERanalysis/qT1/workflow_qT1/sliceqc_flow/_subject_id_35-T1/sf".
# 190411-10:37:17,852 nipype.workflow INFO:
# 	 [Node] Running "sf" ("nipype.interfaces.io.SelectFiles")
# 190411-10:37:18,256 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 23 jobs ready. Free memory (GB): 28.40/28.80, Free processors: 0/2.
#                      Currently running:
#                        * sliceqc_flow.sf
#                        * sliceqc_flow.datasink
# 190411-10:37:18,686 nipype.workflow INFO:
# 	 [Node] Finished "sliceqc_flow.sf".
# 190411-10:37:18,912 nipype.workflow INFO:
# 	 [Node] Finished "sliceqc_flow.datasink".
# 190411-10:37:20,258 nipype.workflow INFO:
# 	 [Job 41] Completed (sliceqc_flow.datasink).
# 190411-10:37:20,259 nipype.workflow INFO:
# 	 [Job 42] Completed (sliceqc_flow.sf).
# 190411-10:37:20,261 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 24 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 2/2.
# 190411-10:37:20,428 nipype.workflow INFO:
# 	 [Node] Setting-up "sliceqc_flow.slices" in "/Volumes/group/proc/TIGERanalysis/qT1/workflow_qT1/sliceqc_flow/_subject_id_35-T1/slices".
# 190411-10:37:20,430 nipype.workflow INFO:
# 	 [Node] Setting-up "sliceqc_flow.sf" in "/Volumes/group/proc/TIGERanalysis/qT1/workflow_qT1/sliceqc_flow/_subject_id_32-T1/sf".
# 190411-10:37:22,263 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 22 jobs ready. Free memory (GB): 28.40/28.80, Free processors: 0/2.
#                      Currently running:
#                        * sliceqc_flow.sf
#                        * sliceqc_flow.slices
# 190411-10:37:23,318 nipype.workflow INFO:
# 	 [Node] Running "sf" ("nipype.interfaces.io.SelectFiles")190411-10:37:23,370 nipype.workflow INFO:
# 	 [Node] Running "slices" ("nipype.interfaces.fsl.utils.Slicer"), a CommandLine Interface with command:
# slicer /Volumes/group/proc/TIGERanalysis/qT1/subjDir/35-T1/qt1_T1fit_final.nii.gz -L  -A 1000 qT1_fitted_QC.png
#
# 190411-10:37:24,67 nipype.workflow INFO:
# 	 [Node] Finished "sliceqc_flow.sf".
# 190411-10:37:24,262 nipype.workflow INFO:
# 	 [Job 45] Completed (sliceqc_flow.sf).
# 190411-10:37:24,265 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 23 jobs ready. Free memory (GB): 28.60/28.80, Free processors: 1/2.
#                      Currently running:
#                        * sliceqc_flow.slices
# 190411-10:37:24,436 nipype.workflow INFO:
# 	 [Node] Setting-up "sliceqc_flow.slices" in "/Volumes/group/proc/TIGERanalysis/qT1/workflow_qT1/sliceqc_flow/_subject_id_32-T1/slices".
# 190411-10:37:25,858 nipype.workflow INFO:
# 	 [Node] Running "slices" ("nipype.interfaces.fsl.utils.Slicer"), a CommandLine Interface with command:
# slicer /Volumes/group/proc/TIGERanalysis/qT1/subjDir/32-T1/qt1_T1fit_final.nii.gz -L  -A 1000 qT1_fitted_QC.png
# 190411-10:37:26,266 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 22 jobs ready. Free memory (GB): 28.40/28.80, Free processors: 0/2.
#                      Currently running:
#                        * sliceqc_flow.slices
#                        * sliceqc_flow.slices
# 190411-10:37:26,506 nipype.workflow INFO:
# 	 [Node] Finished "sliceqc_flow.slices".
# 190411-10:37:28,269 nipype.workflow INFO:
# 	 [Job 43] Completed (sliceqc_flow.slices).
# 190411-10:37:28,271 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 23 jobs ready. Free memory (GB): 28.60/28.80, Free processors: 1/2.
#                      Currently running:
#                        * sliceqc_flow.slices
# 190411-10:37:28,739 nipype.workflow INFO:
# 	 [Node] Setting-up "sliceqc_flow.datasink" in "/Volumes/group/proc/TIGERanalysis/qT1/workflow_qT1/sliceqc_flow/_subject_id_35-T1/datasink".190411-10:37:30,211 nipype.workflow INFO:
# 	 [Node] Finished "sliceqc_flow.slices".
#
# 190411-10:37:30,269 nipype.workflow INFO:
# 	 [Job 46] Completed (sliceqc_flow.slices).
# 190411-10:37:30,272 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 23 jobs ready. Free memory (GB): 28.60/28.80, Free processors: 1/2.
#                      Currently running:
#                        * sliceqc_flow.datasink
# 190411-10:37:30,768 nipype.workflow INFO:
# 	 [Node] Setting-up "sliceqc_flow.datasink" in "/Volumes/group/proc/TIGERanalysis/qT1/workflow_qT1/sliceqc_flow/_subject_id_32-T1/datasink".190411-10:37:31,33 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
#
# 190411-10:37:32,270 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 22 jobs ready. Free memory (GB): 28.40/28.80, Free processors: 0/2.
#                      Currently running:
#                        * sliceqc_flow.datasink
#                        * sliceqc_flow.datasink
# 190411-10:37:32,674 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 190411-10:37:34,354 nipype.workflow INFO:
# 	 [Node] Finished "sliceqc_flow.datasink".
# 190411-10:37:36,272 nipype.workflow INFO:
# 	 [Job 44] Completed (sliceqc_flow.datasink).
# 190411-10:37:36,274 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 22 jobs ready. Free memory (GB): 28.60/28.80, Free processors: 1/2.
#                      Currently running:
#                        * sliceqc_flow.datasink
# 190411-10:37:36,658 nipype.workflow INFO:
# 	 [Node] Finished "sliceqc_flow.datasink".190411-10:37:36,386 nipype.workflow INFO:
# 	 [Node] Setting-up "sliceqc_flow.sf" in "/Volumes/group/proc/TIGERanalysis/qT1/workflow_qT1/sliceqc_flow/_subject_id_31-T1/sf".
#
# 190411-10:37:37,508 nipype.workflow INFO:
# 	 [Node] Running "sf" ("nipype.interfaces.io.SelectFiles")
# 190411-10:37:38,180 nipype.workflow INFO:
# 	 [Node] Finished "sliceqc_flow.sf".
# 190411-10:37:38,273 nipype.workflow INFO:
# 	 [Job 47] Completed (sliceqc_flow.datasink).
# 190411-10:37:38,275 nipype.workflow INFO:
# 	 [Job 48] Completed (sliceqc_flow.sf).
# 190411-10:37:38,277 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 22 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 2/2.
# 190411-10:37:38,448 nipype.workflow INFO:
# 	 [Node] Setting-up "sliceqc_flow.slices" in "/Volumes/group/proc/TIGERanalysis/qT1/workflow_qT1/sliceqc_flow/_subject_id_31-T1/slices".
# 190411-10:37:38,450 nipype.workflow INFO:
# 	 [Node] Setting-up "sliceqc_flow.sf" in "/Volumes/group/proc/TIGERanalysis/qT1/workflow_qT1/sliceqc_flow/_subject_id_30-T1/sf".
# 190411-10:37:40,277 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 20 jobs ready. Free memory (GB): 28.40/28.80, Free processors: 0/2.
#                      Currently running:
#                        * sliceqc_flow.sf
#                        * sliceqc_flow.slices
# 190411-10:37:40,776 nipype.workflow INFO:
# 	 [Node] Running "sf" ("nipype.interfaces.io.SelectFiles")190411-10:37:40,883 nipype.workflow INFO:
# 	 [Node] Running "slices" ("nipype.interfaces.fsl.utils.Slicer"), a CommandLine Interface with command:
# slicer /Volumes/group/proc/TIGERanalysis/qT1/subjDir/31-T1/qt1_T1fit_final.nii.gz -L  -A 1000 qT1_fitted_QC.png
#
# 190411-10:37:41,634 nipype.workflow INFO:
# 	 [Node] Finished "sliceqc_flow.sf".
# 190411-10:37:42,279 nipype.workflow INFO:
# 	 [Job 51] Completed (sliceqc_flow.sf).
# 190411-10:37:42,281 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 21 jobs ready. Free memory (GB): 28.60/28.80, Free processors: 1/2.
#                      Currently running:
#                        * sliceqc_flow.slices
# 190411-10:37:42,457 nipype.workflow INFO:
# 	 [Node] Setting-up "sliceqc_flow.slices" in "/Volumes/group/proc/TIGERanalysis/qT1/workflow_qT1/sliceqc_flow/_subject_id_30-T1/slices".
# 190411-10:37:44,285 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 20 jobs ready. Free memory (GB): 28.40/28.80, Free processors: 0/2.
#                      Currently running:
#                        * sliceqc_flow.slices
#                        * sliceqc_flow.slices
# 190411-10:37:45,852 nipype.workflow INFO:
# 	 [Node] Running "slices" ("nipype.interfaces.fsl.utils.Slicer"), a CommandLine Interface with command:
# slicer /Volumes/group/proc/TIGERanalysis/qT1/subjDir/30-T1/qt1_T1fit_final.nii.gz -L  -A 1000 qT1_fitted_QC.png
# 190411-10:37:47,89 nipype.workflow INFO:
# 	 [Node] Finished "sliceqc_flow.slices".
# 190411-10:37:48,290 nipype.workflow INFO:
# 	 [Job 49] Completed (sliceqc_flow.slices).
# 190411-10:37:48,292 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 21 jobs ready. Free memory (GB): 28.60/28.80, Free processors: 1/2.
#                      Currently running:
#                        * sliceqc_flow.slices
# 190411-10:37:48,823 nipype.workflow INFO:
# 	 [Node] Setting-up "sliceqc_flow.datasink" in "/Volumes/group/proc/TIGERanalysis/qT1/workflow_qT1/sliceqc_flow/_subject_id_31-T1/datasink".
# 190411-10:37:49,502 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 190411-10:37:50,292 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 20 jobs ready. Free memory (GB): 28.40/28.80, Free processors: 0/2.
#                      Currently running:
#                        * sliceqc_flow.datasink
#                        * sliceqc_flow.slices
# 190411-10:37:50,480 nipype.workflow INFO:
# 	 [Node] Finished "sliceqc_flow.slices".
# 190411-10:37:51,802 nipype.workflow INFO:
# 	 [Node] Finished "sliceqc_flow.datasink".
# 190411-10:37:52,292 nipype.workflow INFO:
# 	 [Job 52] Completed (sliceqc_flow.slices).
# 190411-10:37:52,293 nipype.workflow INFO:
# 	 [Job 50] Completed (sliceqc_flow.datasink).
# 190411-10:37:52,296 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 21 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 2/2.
# 190411-10:37:52,466 nipype.workflow INFO:
# 	 [Node] Setting-up "sliceqc_flow.datasink" in "/Volumes/group/proc/TIGERanalysis/qT1/workflow_qT1/sliceqc_flow/_subject_id_30-T1/datasink".
# 190411-10:37:52,468 nipype.workflow INFO:
# 	 [Node] Setting-up "sliceqc_flow.sf" in "/Volumes/group/proc/TIGERanalysis/qT1/workflow_qT1/sliceqc_flow/_subject_id_29-T1/sf".
# 190411-10:37:53,834 nipype.workflow INFO:
# 	 [Node] Running "sf" ("nipype.interfaces.io.SelectFiles")190411-10:37:53,732 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
#
# 190411-10:37:54,295 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 19 jobs ready. Free memory (GB): 28.40/28.80, Free processors: 0/2.
#                      Currently running:
#                        * sliceqc_flow.sf
#                        * sliceqc_flow.datasink
# 190411-10:37:54,955 nipype.workflow INFO:
# 	 [Node] Finished "sliceqc_flow.sf".
# 190411-10:37:56,182 nipype.workflow INFO:
# 	 [Node] Finished "sliceqc_flow.datasink".
# 190411-10:37:56,298 nipype.workflow INFO:
# 	 [Job 53] Completed (sliceqc_flow.datasink).
# 190411-10:37:56,299 nipype.workflow INFO:
# 	 [Job 54] Completed (sliceqc_flow.sf).
# 190411-10:37:56,301 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 20 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 2/2.
# 190411-10:37:56,469 nipype.workflow INFO:
# 	 [Node] Setting-up "sliceqc_flow.slices" in "/Volumes/group/proc/TIGERanalysis/qT1/workflow_qT1/sliceqc_flow/_subject_id_29-T1/slices".
# 190411-10:37:56,471 nipype.workflow INFO:
# 	 [Node] Setting-up "sliceqc_flow.sf" in "/Volumes/group/proc/TIGERanalysis/qT1/workflow_qT1/sliceqc_flow/_subject_id_24-T1/sf".
# 190411-10:37:58,299 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 18 jobs ready. Free memory (GB): 28.40/28.80, Free processors: 0/2.
#                      Currently running:
#                        * sliceqc_flow.sf
#                        * sliceqc_flow.slices
# 190411-10:37:57,816 nipype.workflow INFO:
# 	 [Node] Running "sf" ("nipype.interfaces.io.SelectFiles")190411-10:37:58,324 nipype.workflow INFO:
# 	 [Node] Running "slices" ("nipype.interfaces.fsl.utils.Slicer"), a CommandLine Interface with command:
# slicer /Volumes/group/proc/TIGERanalysis/qT1/subjDir/29-T1/qt1_T1fit_final.nii.gz -L  -A 1000 qT1_fitted_QC.png
#
# 190411-10:37:59,17 nipype.workflow INFO:
# 	 [Node] Finished "sliceqc_flow.sf".
# 190411-10:37:59,890 nipype.workflow INFO:
# 	 [Node] Finished "sliceqc_flow.slices".
# 190411-10:38:00,301 nipype.workflow INFO:
# 	 [Job 55] Completed (sliceqc_flow.slices).
# 190411-10:38:00,302 nipype.workflow INFO:
# 	 [Job 57] Completed (sliceqc_flow.sf).
# 190411-10:38:00,305 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 20 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 2/2.
# 190411-10:38:00,474 nipype.workflow INFO:
# 	 [Node] Setting-up "sliceqc_flow.datasink" in "/Volumes/group/proc/TIGERanalysis/qT1/workflow_qT1/sliceqc_flow/_subject_id_29-T1/datasink".
# 190411-10:38:00,641 nipype.workflow INFO:
# 	 [Node] Setting-up "sliceqc_flow.slices" in "/Volumes/group/proc/TIGERanalysis/qT1/workflow_qT1/sliceqc_flow/_subject_id_24-T1/slices".190411-10:38:01,979 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
#
# 190411-10:38:02,304 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 18 jobs ready. Free memory (GB): 28.40/28.80, Free processors: 0/2.
#                      Currently running:
#                        * sliceqc_flow.slices
#                        * sliceqc_flow.datasink
# 190411-10:38:04,641 nipype.workflow INFO:
# 	 [Node] Running "slices" ("nipype.interfaces.fsl.utils.Slicer"), a CommandLine Interface with command:
# slicer /Volumes/group/proc/TIGERanalysis/qT1/subjDir/24-T1/qt1_T1fit_final.nii.gz -L  -A 1000 qT1_fitted_QC.png
# 190411-10:38:05,555 nipype.workflow INFO:
# 	 [Node] Finished "sliceqc_flow.datasink".
# 190411-10:38:06,307 nipype.workflow INFO:
# 	 [Job 56] Completed (sliceqc_flow.datasink).
# 190411-10:38:06,309 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 18 jobs ready. Free memory (GB): 28.60/28.80, Free processors: 1/2.
#                      Currently running:
#                        * sliceqc_flow.slices
# 190411-10:38:06,423 nipype.workflow INFO:
# 	 [Node] Setting-up "sliceqc_flow.sf" in "/Volumes/group/proc/TIGERanalysis/qT1/workflow_qT1/sliceqc_flow/_subject_id_23-T1/sf".
# 190411-10:38:08,309 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 17 jobs ready. Free memory (GB): 28.40/28.80, Free processors: 0/2.
#                      Currently running:
#                        * sliceqc_flow.sf
#                        * sliceqc_flow.slices
# 190411-10:38:09,521 nipype.workflow INFO:
# 	 [Node] Running "sf" ("nipype.interfaces.io.SelectFiles")
# 190411-10:38:09,789 nipype.workflow INFO:
# 	 [Node] Finished "sliceqc_flow.slices".
# 190411-10:38:10,310 nipype.workflow INFO:
# 	 [Job 58] Completed (sliceqc_flow.slices).
# 190411-10:38:10,312 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 18 jobs ready. Free memory (GB): 28.60/28.80, Free processors: 1/2.
#                      Currently running:
#                        * sliceqc_flow.sf
# 190411-10:38:10,568 nipype.workflow INFO:
# 	 [Node] Setting-up "sliceqc_flow.datasink" in "/Volumes/group/proc/TIGERanalysis/qT1/workflow_qT1/sliceqc_flow/_subject_id_24-T1/datasink".
# 190411-10:38:10,938 nipype.workflow INFO:
# 	 [Node] Finished "sliceqc_flow.sf".190411-10:38:11,467 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
#
# 190411-10:38:12,311 nipype.workflow INFO:
# 	 [Job 60] Completed (sliceqc_flow.sf).
# 190411-10:38:12,313 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 18 jobs ready. Free memory (GB): 28.60/28.80, Free processors: 1/2.
#                      Currently running:
#                        * sliceqc_flow.datasink
# 190411-10:38:13,911 nipype.workflow INFO:
# ...
# 190411-10:39:53,52 nipype.workflow INFO:
# 	 [Node] Setting-up "sliceqc_flow.slices" in "/Volumes/group/proc/TIGERanalysis/qT1/workflow_qT1/sliceqc_flow/_subject_id_11-T1/slices".190411-10:39:53,505 nipype.workflow INFO:
# 	 [Node] Running "slices" ("nipype.interfaces.fsl.utils.Slicer"), a CommandLine Interface with command:
# slicer /Volumes/group/proc/TIGERanalysis/qT1/subjDir/12-T1/qt1_T1fit_final.nii.gz -L  -A 1000 qT1_fitted_QC.png
#
# 190411-10:39:54,247 nipype.workflow INFO:
# 	 [Node] Running "slices" ("nipype.interfaces.fsl.utils.Slicer"), a CommandLine Interface with command:
# slicer /Volumes/group/proc/TIGERanalysis/qT1/subjDir/11-T1/qt1_T1fit_final.nii.gz -L  -A 1000 qT1_fitted_QC.png
# 190411-10:39:54,407 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 6 jobs ready. Free memory (GB): 28.40/28.80, Free processors: 0/2.
#                      Currently running:
#                        * sliceqc_flow.slices
#                        * sliceqc_flow.slices
# 190411-10:39:58,21 nipype.workflow INFO:
# 	 [Node] Finished "sliceqc_flow.slices".
# 190411-10:39:58,266 nipype.workflow INFO:
# 	 [Node] Finished "sliceqc_flow.slices".
# 190411-10:39:58,407 nipype.workflow INFO:
# 	 [Job 91] Completed (sliceqc_flow.slices).
# 190411-10:39:58,409 nipype.workflow INFO:
# 	 [Job 94] Completed (sliceqc_flow.slices).
# 190411-10:39:58,411 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 8 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 2/2.
# 190411-10:39:58,536 nipype.workflow INFO:
# 	 [Node] Setting-up "sliceqc_flow.datasink" in "/Volumes/group/proc/TIGERanalysis/qT1/workflow_qT1/sliceqc_flow/_subject_id_12-T1/datasink".
# 190411-10:39:58,789 nipype.workflow INFO:
# 	 [Node] Setting-up "sliceqc_flow.datasink" in "/Volumes/group/proc/TIGERanalysis/qT1/workflow_qT1/sliceqc_flow/_subject_id_11-T1/datasink".190411-10:39:59,419 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
#
# 190411-10:40:00,410 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 6 jobs ready. Free memory (GB): 28.40/28.80, Free processors: 0/2.
#                      Currently running:
#                        * sliceqc_flow.datasink
#                        * sliceqc_flow.datasink
# 190411-10:40:01,485 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 190411-10:40:03,456 nipype.workflow INFO:
# 	 [Node] Finished "sliceqc_flow.datasink".
# 190411-10:40:04,304 nipype.workflow INFO:
# 	 [Node] Finished "sliceqc_flow.datasink".
# 190411-10:40:04,416 nipype.workflow INFO:
# 	 [Job 92] Completed (sliceqc_flow.datasink).
# 190411-10:40:04,417 nipype.workflow INFO:
# 	 [Job 95] Completed (sliceqc_flow.datasink).
# 190411-10:40:04,420 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 6 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 2/2.
# 190411-10:40:04,544 nipype.workflow INFO:
# 	 [Node] Setting-up "sliceqc_flow.sf" in "/Volumes/group/proc/TIGERanalysis/qT1/workflow_qT1/sliceqc_flow/_subject_id_10-T1/sf".
# 190411-10:40:04,546 nipype.workflow INFO:
# 	 [Node] Setting-up "sliceqc_flow.sf" in "/Volumes/group/proc/TIGERanalysis/qT1/workflow_qT1/sliceqc_flow/_subject_id_09-T2/sf".
# 190411-10:40:06,417 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 4 jobs ready. Free memory (GB): 28.40/28.80, Free processors: 0/2.
#                      Currently running:
#                        * sliceqc_flow.sf
#                        * sliceqc_flow.sf
# 190411-10:40:06,994 nipype.workflow INFO:
# 	 [Node] Running "sf" ("nipype.interfaces.io.SelectFiles")190411-10:40:07,136 nipype.workflow INFO:
# 	 [Node] Running "sf" ("nipype.interfaces.io.SelectFiles")
#
# 190411-10:40:07,846 nipype.workflow INFO:
# 	 [Node] Finished "sliceqc_flow.sf".
# 190411-10:40:08,11 nipype.workflow INFO:
# 	 [Node] Finished "sliceqc_flow.sf".
# 190411-10:40:08,418 nipype.workflow INFO:
# 	 [Job 96] Completed (sliceqc_flow.sf).
# 190411-10:40:08,419 nipype.workflow INFO:
# 	 [Job 99] Completed (sliceqc_flow.sf).
# 190411-10:40:08,422 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 6 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 2/2.
# 190411-10:40:08,591 nipype.workflow INFO:
# 	 [Node] Setting-up "sliceqc_flow.slices" in "/Volumes/group/proc/TIGERanalysis/qT1/workflow_qT1/sliceqc_flow/_subject_id_10-T1/slices".
# 190411-10:40:08,797 nipype.workflow INFO:
# 	 [Node] Setting-up "sliceqc_flow.slices" in "/Volumes/group/proc/TIGERanalysis/qT1/workflow_qT1/sliceqc_flow/_subject_id_09-T2/slices".190411-10:40:09,299 nipype.workflow INFO:
# 	 [Node] Running "slices" ("nipype.interfaces.fsl.utils.Slicer"), a CommandLine Interface with command:
# slicer /Volumes/group/proc/TIGERanalysis/qT1/subjDir/10-T1/qt1_T1fit_final.nii.gz -L  -A 1000 qT1_fitted_QC.png
#
# 190411-10:40:10,323 nipype.workflow INFO:
# 	 [Node] Running "slices" ("nipype.interfaces.fsl.utils.Slicer"), a CommandLine Interface with command:
# slicer /Volumes/group/proc/TIGERanalysis/qT1/subjDir/09-T2/qt1_T1fit_final.nii.gz -L  -A 1000 qT1_fitted_QC.png
# 190411-10:40:10,424 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 4 jobs ready. Free memory (GB): 28.40/28.80, Free processors: 0/2.
#                      Currently running:
#                        * sliceqc_flow.slices
#                        * sliceqc_flow.slices
# 190411-10:40:12,330 nipype.workflow INFO:
# 	 [Node] Finished "sliceqc_flow.slices".
# 190411-10:40:12,977 nipype.workflow INFO:
# 	 [Node] Finished "sliceqc_flow.slices".
# 190411-10:40:14,426 nipype.workflow INFO:
# 	 [Job 97] Completed (sliceqc_flow.slices).
# 190411-10:40:14,427 nipype.workflow INFO:
# 	 [Job 100] Completed (sliceqc_flow.slices).
# 190411-10:40:14,430 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 6 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 2/2.
# 190411-10:40:14,610 nipype.workflow INFO:
# 	 [Node] Setting-up "sliceqc_flow.datasink" in "/Volumes/group/proc/TIGERanalysis/qT1/workflow_qT1/sliceqc_flow/_subject_id_10-T1/datasink".
# 190411-10:40:14,815 nipype.workflow INFO:
# 	 [Node] Setting-up "sliceqc_flow.datasink" in "/Volumes/group/proc/TIGERanalysis/qT1/workflow_qT1/sliceqc_flow/_subject_id_09-T2/datasink".190411-10:40:15,924 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
#
# 190411-10:40:16,431 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 4 jobs ready. Free memory (GB): 28.40/28.80, Free processors: 0/2.
#                      Currently running:
#                        * sliceqc_flow.datasink
#                        * sliceqc_flow.datasink
# 190411-10:40:17,201 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 190411-10:40:18,153 nipype.workflow INFO:
# 	 [Node] Finished "sliceqc_flow.datasink".
# 190411-10:40:18,430 nipype.workflow INFO:
# 	 [Job 98] Completed (sliceqc_flow.datasink).
# 190411-10:40:18,433 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 4 jobs ready. Free memory (GB): 28.60/28.80, Free processors: 1/2.
#                      Currently running:
#                        * sliceqc_flow.datasink
# 190411-10:40:18,560 nipype.workflow INFO:
# 	 [Node] Setting-up "sliceqc_flow.sf" in "/Volumes/group/proc/TIGERanalysis/qT1/workflow_qT1/sliceqc_flow/_subject_id_08-T1/sf".190411-10:40:18,936 nipype.workflow INFO:
# 	 [Node] Finished "sliceqc_flow.datasink".
#
# 190411-10:40:20,124 nipype.workflow INFO:
# 	 [Node] Running "sf" ("nipype.interfaces.io.SelectFiles")
# 190411-10:40:20,432 nipype.workflow INFO:
# 	 [Job 101] Completed (sliceqc_flow.datasink).
# 190411-10:40:20,434 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 3 jobs ready. Free memory (GB): 28.60/28.80, Free processors: 1/2.
#                      Currently running:
#                        * sliceqc_flow.sf
# 190411-10:40:20,553 nipype.workflow INFO:
# 	 [Node] Setting-up "sliceqc_flow.sf" in "/Volumes/group/proc/TIGERanalysis/qT1/workflow_qT1/sliceqc_flow/_subject_id_07-T2/sf".190411-10:40:20,726 nipype.workflow INFO:
# 	 [Node] Finished "sliceqc_flow.sf".
#
# 190411-10:40:22,434 nipype.workflow INFO:
# 	 [Job 102] Completed (sliceqc_flow.sf).
# 190411-10:40:22,436 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 3 jobs ready. Free memory (GB): 28.60/28.80, Free processors: 1/2.
#                      Currently running:
#                        * sliceqc_flow.sf
# 190411-10:40:23,533 nipype.workflow INFO:
# 	 [Node] Running "sf" ("nipype.interfaces.io.SelectFiles")
# 190411-10:40:23,578 nipype.workflow INFO:
# 	 [Node] Setting-up "sliceqc_flow.slices" in "/Volumes/group/proc/TIGERanalysis/qT1/workflow_qT1/sliceqc_flow/_subject_id_08-T1/slices".
# 190411-10:40:24,440 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 2 jobs ready. Free memory (GB): 28.40/28.80, Free processors: 0/2.
#                      Currently running:
#                        * sliceqc_flow.slices
#                        * sliceqc_flow.sf
# 190411-10:40:25,990 nipype.workflow INFO:
# 	 [Node] Running "slices" ("nipype.interfaces.fsl.utils.Slicer"), a CommandLine Interface with command:
# slicer /Volumes/group/proc/TIGERanalysis/qT1/subjDir/08-T1/qt1_T1fit_final.nii.gz -L  -A 1000 qT1_fitted_QC.png190411-10:40:25,582 nipype.workflow INFO:
# 	 [Node] Finished "sliceqc_flow.sf".
#
# 190411-10:40:26,439 nipype.workflow INFO:
# 	 [Job 105] Completed (sliceqc_flow.sf).
# 190411-10:40:26,442 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 3 jobs ready. Free memory (GB): 28.60/28.80, Free processors: 1/2.
#                      Currently running:
#                        * sliceqc_flow.slices
# 190411-10:40:26,669 nipype.workflow INFO:
# 	 [Node] Setting-up "sliceqc_flow.slices" in "/Volumes/group/proc/TIGERanalysis/qT1/workflow_qT1/sliceqc_flow/_subject_id_07-T2/slices".
# 190411-10:40:27,703 nipype.workflow INFO:
# 	 [Node] Running "slices" ("nipype.interfaces.fsl.utils.Slicer"), a CommandLine Interface with command:
# slicer /Volumes/group/proc/TIGERanalysis/qT1/subjDir/07-T2/qt1_T1fit_final.nii.gz -L  -A 1000 qT1_fitted_QC.png
# 190411-10:40:28,440 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 2 jobs ready. Free memory (GB): 28.40/28.80, Free processors: 0/2.
#                      Currently running:
#                        * sliceqc_flow.slices
#                        * sliceqc_flow.slices
# 190411-10:40:28,899 nipype.workflow INFO:
# 	 [Node] Finished "sliceqc_flow.slices".
# 190411-10:40:30,442 nipype.workflow INFO:
# 	 [Job 103] Completed (sliceqc_flow.slices).
# 190411-10:40:30,448 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 3 jobs ready. Free memory (GB): 28.60/28.80, Free processors: 1/2.
#                      Currently running:
#                        * sliceqc_flow.slices
# 190411-10:40:30,869 nipype.workflow INFO:
# 	 [Node] Setting-up "sliceqc_flow.datasink" in "/Volumes/group/proc/TIGERanalysis/qT1/workflow_qT1/sliceqc_flow/_subject_id_08-T1/datasink".190411-10:40:32,44 nipype.workflow INFO:
# 	 [Node] Finished "sliceqc_flow.slices".
#
# 190411-10:40:32,446 nipype.workflow INFO:
# 	 [Job 106] Completed (sliceqc_flow.slices).
# 190411-10:40:32,448 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 3 jobs ready. Free memory (GB): 28.60/28.80, Free processors: 1/2.
#                      Currently running:
#                        * sliceqc_flow.datasink
# 190411-10:40:33,522 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 190411-10:40:33,571 nipype.workflow INFO:
# 	 [Node] Setting-up "sliceqc_flow.datasink" in "/Volumes/group/proc/TIGERanalysis/qT1/workflow_qT1/sliceqc_flow/_subject_id_07-T2/datasink".
# 190411-10:40:34,448 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 2 jobs ready. Free memory (GB): 28.40/28.80, Free processors: 0/2.
#                      Currently running:
#                        * sliceqc_flow.datasink
#                        * sliceqc_flow.datasink
# 190411-10:40:35,388 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 190411-10:40:37,133 nipype.workflow INFO:
# 	 [Node] Finished "sliceqc_flow.datasink".
# 190411-10:40:37,948 nipype.workflow INFO:
# 	 [Node] Finished "sliceqc_flow.datasink".
# 190411-10:40:38,448 nipype.workflow INFO:
# 	 [Job 104] Completed (sliceqc_flow.datasink).
# 190411-10:40:38,450 nipype.workflow INFO:
# 	 [Job 107] Completed (sliceqc_flow.datasink).
# 190411-10:40:38,453 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 2 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 2/2.
# 190411-10:40:38,567 nipype.workflow INFO:
# 	 [Node] Setting-up "sliceqc_flow.sf" in "/Volumes/group/proc/TIGERanalysis/qT1/workflow_qT1/sliceqc_flow/_subject_id_06-T1/sf".
# 190411-10:40:38,598 nipype.workflow INFO:
# 	 [Node] Setting-up "sliceqc_flow.sf" in "/Volumes/group/proc/TIGERanalysis/qT1/workflow_qT1/sliceqc_flow/_subject_id_02-T2/sf".
# 190411-10:40:39,858 nipype.workflow INFO:
# 	 [Node] Running "sf" ("nipype.interfaces.io.SelectFiles")190411-10:40:40,259 nipype.workflow INFO:
# 	 [Node] Running "sf" ("nipype.interfaces.io.SelectFiles")
#
# 190411-10:40:40,449 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 0 jobs ready. Free memory (GB): 28.40/28.80, Free processors: 0/2.
#                      Currently running:
#                        * sliceqc_flow.sf
#                        * sliceqc_flow.sf
# 190411-10:40:40,894 nipype.workflow INFO:
# 	 [Node] Finished "sliceqc_flow.sf".
# 190411-10:40:41,91 nipype.workflow INFO:
# 	 [Node] Finished "sliceqc_flow.sf".
# 190411-10:40:42,451 nipype.workflow INFO:
# 	 [Job 108] Completed (sliceqc_flow.sf).
# 190411-10:40:42,452 nipype.workflow INFO:
# 	 [Job 111] Completed (sliceqc_flow.sf).
# 190411-10:40:42,455 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 2 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 2/2.
# 190411-10:40:42,625 nipype.workflow INFO:
# 	 [Node] Setting-up "sliceqc_flow.slices" in "/Volumes/group/proc/TIGERanalysis/qT1/workflow_qT1/sliceqc_flow/_subject_id_06-T1/slices".
# 190411-10:40:42,841 nipype.workflow INFO:
# 	 [Job 112] Cached (sliceqc_flow.slices).
# 190411-10:40:43,434 nipype.workflow INFO:
# 	 [Node] Running "slices" ("nipype.interfaces.fsl.utils.Slicer"), a CommandLine Interface with command:
# slicer /Volumes/group/proc/TIGERanalysis/qT1/subjDir/06-T1/qt1_T1fit_final.nii.gz -L  -A 1000 qT1_fitted_QC.png
# 190411-10:40:44,451 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 1 jobs ready. Free memory (GB): 28.60/28.80, Free processors: 1/2.
#                      Currently running:
#                        * sliceqc_flow.slices
# 190411-10:40:44,592 nipype.workflow INFO:
# 	 [Node] Setting-up "sliceqc_flow.datasink" in "/Volumes/group/proc/TIGERanalysis/qT1/workflow_qT1/sliceqc_flow/_subject_id_02-T2/datasink".
# 190411-10:40:46,248 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")190411-10:40:46,376 nipype.workflow INFO:
# 	 [Node] Finished "sliceqc_flow.slices".
#
# 190411-10:40:46,451 nipype.workflow INFO:
# 	 [Job 109] Completed (sliceqc_flow.slices).
# 190411-10:40:46,454 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 1 jobs ready. Free memory (GB): 28.60/28.80, Free processors: 1/2.
#                      Currently running:
#                        * sliceqc_flow.datasink
# 190411-10:40:46,751 nipype.workflow INFO:
# 	 [Node] Setting-up "sliceqc_flow.datasink" in "/Volumes/group/proc/TIGERanalysis/qT1/workflow_qT1/sliceqc_flow/_subject_id_06-T1/datasink".
# 190411-10:40:46,875 nipype.workflow INFO:
# 	 [Node] Finished "sliceqc_flow.datasink".
# 190411-10:40:48,453 nipype.workflow INFO:
# 	 [Job 113] Completed (sliceqc_flow.datasink).
# 190411-10:40:48,456 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 28.60/28.80, Free processors: 1/2.
#                      Currently running:
#                        * sliceqc_flow.datasink
# 190411-10:40:49,654 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 190411-10:40:50,726 nipype.workflow INFO:
# 	 [Node] Finished "sliceqc_flow.datasink".
# 190411-10:40:52,454 nipype.workflow INFO:
# 	 [Job 110] Completed (sliceqc_flow.datasink).
# 190411-10:40:52,457 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 0 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 2/2.
